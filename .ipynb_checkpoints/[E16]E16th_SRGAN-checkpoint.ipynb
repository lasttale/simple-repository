# %% [markdown]
# # 16 SRGAN 활용하기

# %% [markdown]
# ## 16.1-1 직접 고른 이미지로 SRGAN  실험하기
#
# (적당히) 높은 해상도를 가진 이미지를 검색해서 한 장 고른 후 저장하고 불러옵니다.
# 불러온 이미지에 bicubic interpolation을 적용해 가로 및 세로 픽셀 수를 1/4로 줄입니다. cv2.resize()를 사용해 봅시다.
# 줄인 저해상도 이미지를 입력으로 SRGAN을 이용해 고해상도 이미지를 생성합니다. 이전에 사용한 apply_srgan 함수를 사용하면 쉽습니다.
# 2.의 이미지에 bicubic interpolation을 적용해 가로 및 세로 픽셀 수를 다시 4배로 늘립니다. 마찬가지로 cv2.resize()를 사용해 봅시다.
# 3개 이미지(4.의 Bicubic의 결과, 3.의 SRGAN의 결과, 1.의 원래 고해상도 이미지)를 나란히 시각화합니다. 각 이미지의 제목에 어떤 방법에 대한 결과인지 표시해 주세요. 이전 시각화에 사용했던 코드를 참고하면 어렵지 않습니다.
# 선택한 이미지를 DIV2K 데이터셋에서 학습된 모델로 Super Resolution했을 때 어떠한 결과가 나왔으며, 왜 이러한 결과가 출력되었는지 설명해 봅시다. (정답은 없습니다)

# %%
# 이미지 불러오기

import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

img_path = os.getenv('HOME')+'/aiffel/super_resolution/풍경1.jpg' 
img_orig = cv2.imread(img_path) 
print (img_orig.shape)

plt.figure(figsize=(6,3))
plt.imshow(cv2.cvtColor(img_orig,cv2.COLOR_BGR2RGB))
# Out:
# (1333, 1999, 3)

# %%
# crop 함수 정의

def crop(image, left_top, x=200, y=200):
    return image[left_top[0]:(left_top[0]+x), left_top[1]:(left_top[1]+y), :]

# %%
# bicubic interpolation 적용

bicubic_image = cv2.resize(
    img_orig, 
    dsize=(1999//4, 1333//4), # (가로 픽셀 수, 세로 픽셀 수)
    interpolation=cv2.INTER_CUBIC # bicubic interpolation 적용
)

images = [bicubic_image, img_orig]
titles = ["Bicubic_LR", "HR"]

plt.figure(figsize=(16,3))
for i, (image, title) in enumerate(zip(images, titles)):
    plt.subplot(1,3,i+1)
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title, fontsize=20)

# %%
# 크롭샷으로 비교하기

left_top = (400, 500)
crop_bicubic_image = crop(bicubic_image, left_top)
crop_hr = crop(hr, left_top)

plt.figure(figsize=(15,25))
plt.subplot(1,2,1); plt.imshow(crop_bicubic_image); plt.title("Bicubic", fontsize=30)
plt.subplot(1,2,2); plt.imshow(crop_hr); plt.title("HR", fontsize=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-703f62a28102> in <module>
#       6
#       7 plt.figure(figsize=(15,25))
# ----> 8 plt.subplot(1,2,1); plt.imshow(crop_bicubic_image); plt.title("Bicubic", fontsize=30)
#       9 plt.subplot(1,2,2); plt.imshow(crop_hr); plt.title("HR", fontsize=30)
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     718             # making reliable interpretation impossible.
#     719             high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
# --> 720             if self._A.min() < 0 or high < self._A.max():
#     721                 _log.warning(
#     722                     'Clipping input data to the valid range for imshow with '
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/numpy/ma/core.py in min(self, axis, out, fill_value, keepdims)
#    5699         if out is None:
#    5700             result = self.filled(fill_value).min(
# -> 5701                 axis=axis, out=out, **kwargs).view(type(self))
#    5702             if result.ndim:
#    5703                 # Set the mask
#
# ~/Downloads/aiffel/envs/aiffel/lib/python3.7/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# 학습된 srgan_G.h5 불러오기

import tensorflow as tf

model_file = os.getenv('HOME')+'/aiffel/super_resolution/srgan_G.h5'
srgan = tf.keras.models.load_model(model_file)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# SRGAN을 이용하여 고해상도 이미지 생성

import tensorflow_datasets as tfds

def apply_srgan(image):
    image = tf.cast(image[np.newaxis, ...], tf.float32)
    sr = srgan.predict(image)
    sr = tf.clip_by_value(sr, 0, 255)
    sr = tf.round(sr)
    sr = tf.cast(sr, tf.uint8)
    return np.array(sr)[0]

lr = bicubic_image

srgan_hr = apply_srgan(lr)
print("✅")
# Out:
# ✅

# %%
# bicubic interpolation 활용 고해상도 변환

bicubic_hr = cv2.resize(
    bicubic_image, 
    dsize=(1999, 1333), # (가로 픽셀 수, 세로 픽셀 수)
    interpolation=cv2.INTER_CUBIC # bicubic interpolation 적용
)

# %%
# 3개 이미지 시각화하기

images = [bicubic_hr, srgan_hr, img_orig]
titles = ["Bicubic_LR", "SRGAN_HR", "HR"]

plt.figure(figsize=(16,3))
for i, (image, title) in enumerate(zip(images, titles)):
    plt.subplot(1,3,i+1)
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title, fontsize=20)

# %%
# 크롭샷으로 비교하기

left_top = (900, 1400)
crop_bicubic_hr = crop(bicubic_hr, left_top)
crop_srgan_hr = crop(srgan_hr, left_top)
crop_img_orig = crop(img_orig, left_top)

crop_images = [crop_bicubic_hr, crop_srgan_hr, crop_img_orig]
titles = ["Bicubic_LR", "SRGAN_HR", "HR"]

plt.figure(figsize=(15,25))
for i, (image, title) in enumerate(zip(crop_images, titles)):
    plt.subplot(1,3,i+1)
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title, fontsize=20)
